# %% [markdown]
# ## Fig.1 Cerebellar Flatmaps

# %%
import os
import glob
import nibabel as nb
import SUITPy.flatmap as flatmap
import matplotlib.pyplot as plt
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ### All children

# %%
fdr_data = flatmap.vol_to_surf('/Users/katerina/Desktop/DevCerebToM/figures/contrast_flatmaps/children/one_sample_fdr.nii')
print('Output is a np.array of size:',fdr_data.shape)
# Out:
# Output is a np.array of size: (28935, 1)

# %%
flatmap.plot(data=fdr_data, cmap='hot', \
    threshold=[0.2, 2.8], \
    new_figure=True, \
    colorbar=False, \
    render='matplotlib')
# Out:
# <Axes: >

# %% [markdown]
# ### All Children - ToM Score

# %%
fdr_data = flatmap.vol_to_surf('/Users/katerina/Desktop/DevCerebToM/figures/contrast_flatmaps/children/GLM_fdr.nii')
print('Output is a np.array of size:',fdr_data.shape)
# Out:
# Output is a np.array of size: (28935, 1)

# %%
flatmap.plot(data=fdr_data, cmap='hot', \
    threshold=[0, 1.9], \
    new_figure=True, \
    colorbar=False, \
    render='matplotlib')
# Out:
# <Axes: >

# %% [markdown]
# ### Passers

# %%
fdr_data = flatmap.vol_to_surf('/Users/katerina/Desktop/DevCerebToM/figures/contrast_flatmaps/children/pass/one_sample_fdr.nii')
print('Output is a np.array of size:',fdr_data.shape)
# Out:
# Output is a np.array of size: (28935, 1)

# %%
flatmap.plot(data=fdr_data, cmap='hot', \
    threshold=[0, 1.6], \
    new_figure=True, \
    colorbar=False, \
    render='matplotlib')
# Out:
# <Axes: >

# %% [markdown]
# ### Nonpassers

# %%
fdr_data = flatmap.vol_to_surf('/Users/katerina/Desktop/DevCerebToM/figures/contrast_flatmaps/children/fail/one_sample_fdr.nii')
print('Output is a np.array of size:',fdr_data.shape)
# Out:
# Output is a np.array of size: (28935, 1)

# %%
flatmap.plot(data=fdr_data, cmap='hot', \
    threshold=[0, 0.83], \
    new_figure=True, \
    colorbar=True, \
    render='matplotlib')
# Out:
# <Axes: >

# %% [markdown]
# ### Richardson adults

# %%
fdr_data = flatmap.vol_to_surf('/Users/katerina/Desktop/DevCerebToM/figures/contrast_flatmaps/adults_richardson/one_sample_fdr.nii')
print('Output is a np.array of size:',fdr_data.shape)
# Out:
# Output is a np.array of size: (28935, 1)

# %%
flatmap.plot(data=fdr_data, cmap='hot', \
    threshold=[2, 4.2], \
    new_figure=True, \
    colorbar=False, \
    render='matplotlib')
# Out:
# <Axes: >

# %% [markdown]
# ### CCC adults

# %%
fdr_data = flatmap.vol_to_surf('/Users/katerina/Desktop/DevCerebToM/figures/contrast_flatmaps/adults_ccc/one_sample_fdr.nii')
print('Output is a np.array of size:',fdr_data.shape)
# Out:
# Output is a np.array of size: (28935, 1)

# %%
flatmap.plot(data=fdr_data, cmap='hot', \
    threshold=[1.3, 3.9], \
    new_figure=True, \
    colorbar=False, \
    render='matplotlib')
# Out:
# <Axes: >
